# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Loading the dataset
df = pd.read_csv("heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
df.head()
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                     0       1         1          1   40       1       0
# 1                     0       0         0          0   25       1       0
# 2                     0       1         1          1   28       0       0
# 3                     0       1         0          1   27       0       0
# 4                     0       1         1          1   24       0       0
#
#    Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0         0             0       0  ...              1            0        5
# 1         0             1       0  ...              0            1        3
# 2         0             0       1  ...              1            1        5
# 3         0             1       1  ...              1            0        2
# 4         0             1       1  ...              1            0        2
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# ...

# %%
df.columns
# Out:
# Index(['HeartDiseaseorAttack', 'HighBP', 'HighChol', 'CholCheck', 'BMI',
#        'Smoker', 'Stroke', 'Diabetes', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education',
#        'Income'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
df.describe()
# Out:
#        HeartDiseaseorAttack         HighBP       HighChol      CholCheck  \
# count         253680.000000  253680.000000  253680.000000  253680.000000
# mean               0.094186       0.429001       0.424121       0.962670
# std                0.292087       0.494934       0.494210       0.189571
# min                0.000000       0.000000       0.000000       0.000000
# 25%                0.000000       0.000000       0.000000       1.000000
# 50%                0.000000       0.000000       0.000000       1.000000
# 75%                0.000000       1.000000       1.000000       1.000000
# max                1.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke       Diabetes  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean       28.382364       0.443169       0.040571       0.296921
# std         6.608694       0.496761       0.197294       0.698160
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  int64
#  1   HighBP                253680 non-null  int64
#  2   HighChol              253680 non-null  int64
#  3   CholCheck             253680 non-null  int64
#  4   BMI                   253680 non-null  int64
#  5   Smoker                253680 non-null  int64
#  6   Stroke                253680 non-null  int64
#  7   Diabetes              253680 non-null  int64
#  8   PhysActivity          253680 non-null  int64
#  9   Fruits                253680 non-null  int64
#  10  Veggies               253680 non-null  int64
#  11  HvyAlcoholConsump     253680 non-null  int64
#  12  AnyHealthcare         253680 non-null  int64
#  13  NoDocbcCost           253680 non-null  int64
# ...

# %%
categorical_columns = [
    'HeartDiseaseorAttack', 'HighBP', 'HighChol', 'CholCheck', 'Smoker', 
    'Stroke', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 
    'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'GenHlth', 'Age'
]

# Convert specified columns to categorical
df[categorical_columns] = df[categorical_columns].astype('category')

# Verify the changes
print(df.dtypes)
# Out:
# HeartDiseaseorAttack    category
# HighBP                  category
# HighChol                category
# CholCheck               category
# BMI                        int64
# Smoker                  category
# Stroke                  category
# Diabetes                   int64
# PhysActivity            category
# Fruits                  category
# Veggies                 category
# HvyAlcoholConsump       category
# AnyHealthcare           category
# NoDocbcCost             category
# GenHlth                 category
# MentHlth                   int64
# PhysHlth                   int64
# DiffWalk                category
# Sex                     category
# Age                     category
# Education                  int64
# Income                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  category
#  1   HighBP                253680 non-null  category
#  2   HighChol              253680 non-null  category
#  3   CholCheck             253680 non-null  category
#  4   BMI                   253680 non-null  int64
#  5   Smoker                253680 non-null  category
#  6   Stroke                253680 non-null  category
#  7   Diabetes              253680 non-null  int64
#  8   PhysActivity          253680 non-null  category
#  9   Fruits                253680 non-null  category
#  10  Veggies               253680 non-null  category
#  11  HvyAlcoholConsump     253680 non-null  category
#  12  AnyHealthcare         253680 non-null  category
#  13  NoDocbcCost           253680 non-null  category
# ...

# %% [markdown]
#  # Univariate analysis
#  a. Examine Distributions of Individual Variables:
#         Plot histograms or bar charts to visualize the distribution of key variables such as age, BMI, mental health days (Menthlth), and physical health days (PhysHlth).

# %%
### 1. Distribution of Age (Categorical Variable) ###


# Set the aesthetic style for the plots
sns.set(style="whitegrid")

# Create a figure for the age distribution plot
plt.figure(figsize=(10, 6))

# Plotting the histogram and KDE for Age distribution
sns.histplot(df['Age'], kde=True, bins=30, color='skyblue')

# Add titles and labels
plt.title('Age Distribution of Individuals', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
### 2. Distribution of BMI (Continuous Variable) ###
df['BMI'].plot(kind='hist', bins=10, color='lightgreen', edgecolor='black')
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()
df['BMI'].describe()
# Out:
# count    253680.000000
# mean         28.382364
# std           6.608694
# min          12.000000
# 25%          24.000000
# 50%          27.000000
# 75%          31.000000
# max          98.000000
# Name: BMI, dtype: float64

# %%
### 3. Distribution of MentHlth (Mental Health Days) ###
df['MentHlth'].plot(kind='hist', bins=10, color='lightcoral', edgecolor='black')
plt.title('Distribution of Mental Health Days')
plt.xlabel('Days (Bad Mental Health)')
plt.ylabel('Frequency')

plt.show()
df['MentHlth'].describe()
# Out:
# count    253680.000000
# mean          3.184772
# std           7.412847
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max          30.000000
# Name: MentHlth, dtype: float64

# %%
### 4. Distribution of PhysHlth (Physical Health Days) ###
df['PhysHlth'].plot(kind='hist', bins=10, color='lightblue', edgecolor='black')
plt.title('Distribution of Physical Health Days')
plt.xlabel('Days (Bad Physical Health)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# b. Investigate Prevalence of Health Conditions:
# Plot bar charts or pie charts to show the prevalence of high blood pressure (HighBP), high cholesterol (HighChol), and other health conditions.

# %%
### 1. Prevalence of High Blood Pressure (HighBP) ###
# Bar chart for HighBP
df['HighBP'].value_counts().plot(kind='bar', color=['lightcoral', 'lightgreen'])
plt.title('Prevalence of High Blood Pressure')
plt.xlabel('High Blood Pressure (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()


# Pie chart for HighBP
df['HighBP'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], startangle=90, explode=(0, 0.1))
plt.title('Prevalence of High Blood Pressure')
plt.ylabel('')  # Remove y-label for better aesthetics
plt.show()

# %%
### 2. Prevalence of High Cholesterol (HighChol) ###
# Bar chart for HighChol
df['HighChol'].value_counts().plot(kind='bar', color=['lightblue', 'lightgreen'])
plt.title('Prevalence of High Cholesterol')
plt.xlabel('High Cholesterol (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# Pie chart for HighChol
df['HighChol'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen'], startangle=90, explode=(0, 0.1))
plt.title('Prevalence of High Cholesterol')
plt.ylabel('')  # Remove y-label for better aesthetics
plt.show()

# %%
### 3. Prevalence of Physical Activity (PhysActivity) ###
# Bar chart for Physical Activity
df['PhysActivity'].value_counts().plot(kind='bar', color=['lightgray', 'lightgreen'])
plt.title('Prevalence of Physical Activity')
plt.xlabel('Physical Activity in Last 30 Days (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# Pie chart for Physical Activity
df['PhysActivity'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgray', 'lightgreen'], startangle=90, explode=(0, 0.1))
plt.title('Prevalence of Physical Activity')
plt.ylabel('')  # Remove y-label for better aesthetics
plt.show()

# %% [markdown]
# c. Analyze Distribution of Heart Disease (Target Variable):
# Visualize the distribution of heart disease cases using a bar chart or pie chart.

# %%
### 1. Bar Chart for Heart Disease Distribution ###
df['HeartDiseaseorAttack'].value_counts().plot(kind='bar', color=['lightblue', 'lightgreen'])
plt.title('Distribution of Heart Disease Cases')
plt.xlabel('Heart Disease (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# %%
### 2. Pie Chart for Heart Disease Distribution ###
df['HeartDiseaseorAttack'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen'], startangle=90, explode=(0, 0.1))
plt.title('Distribution of Heart Disease Cases')
plt.ylabel('')  # Remove y-label for better aesthetics
plt.show()

# %% [markdown]
# # Conduct Bivariate analysis:-
# a. Explore Relationships with Heart Disease:
# Compare the distribution of key variables (e.g., HighBP, HighChol, BMI) between individuals with and without heart disease.

# %%
### 1. Comparing HighBP Distribution ###
# Calculate counts for each category
counts = df.groupby(['HighBP', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)
# Create the figure and axes
plt.figure(figsize=(10, 5))
# Plot the bars for each category
counts.plot(kind='bar', stacked=False, color=['lightgreen', 'lightcoral'], ax=plt.gca())
# Set titles and labels
plt.title('High Blood Pressure Distribution by Heart Disease Status')
plt.xlabel('High Blood Pressure (0 = No, 1 = Yes)')
plt.ylabel('Count')
# Set x-ticks and labels
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
# Add legend
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
# Show the plot
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\3756471290.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = df.groupby(['HighBP', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %%
### 2. Comparing HighChol Distribution ###
# Calculate counts for each category
counts = df.groupby(['HighChol', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)
# Create the figure and axes
plt.figure(figsize=(10, 5))
# Plot the bars for each category
counts.plot(kind='bar', stacked=False, color=['lightgreen', 'lightcoral'], ax=plt.gca())
# Set titles and labels
plt.title('High Cholesterol Distribution by Heart Disease Status')
plt.xlabel('High Cholesterol (0 = No, 1 = Yes)')
plt.ylabel('Count')
# Set x-ticks and labels
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
# Add legend
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
# Show the plot
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\507250489.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts = df.groupby(['HighChol', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %%
### 3. Comparing BMI Distribution ###
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='HeartDiseaseorAttack', y='BMI', palette=['lightcoral', 'lightgreen'])
plt.title('BMI Distribution by Heart Disease Status')
plt.xlabel('Heart Disease (0 = No, 1 = Yes)')
plt.ylabel('BMI')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\3631663967.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='HeartDiseaseorAttack', y='BMI', palette=['lightcoral', 'lightgreen'])

# %%
### 4. Compare Smoker Distribution ###
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Smoker', hue='HeartDiseaseorAttack', palette=['lightgreen', 'lightcoral'])
plt.title('Smoking Status Distribution by Heart Disease Status')
plt.xlabel('Smoker (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# b. Visualize Correlations Between Variables:
# Use scatter plots or correlation matrices to explore relationships between continuous variables.

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

### 1. Scatter Plots to visualize relationships between continuous variables ###
plt.figure(figsize=(15, 10))

# Scatter plot for BMI vs Age
plt.subplot(2, 2, 1)
sns.scatterplot(data=df, x='Age', y='BMI', hue='HighBP', style='HighChol', palette='deep')
plt.title('BMI vs Age')
plt.xlabel('Age')
plt.ylabel('BMI')

# Scatter plot for BMI vs. Mental Health Days
plt.subplot(2, 2, 2)
plt.scatter(df['BMI'], df['MentHlth'], color='blue', alpha=0.6)
plt.title('BMI vs. Mental Health Days')
plt.xlabel('BMI')
plt.ylabel('Mental Health Days')

# Scatter plot for BMI vs. Physical Health Days
plt.subplot(2, 2, 3)
plt.scatter(df['BMI'], df['PhysHlth'], color='orange', alpha=0.6)
plt.title('BMI vs. Physical Health Days')
plt.xlabel('BMI')
plt.ylabel('Physical Health Days')

# Scatter plot for Mental Health Days vs. Physical Health Days
plt.subplot(2, 2, 4)
plt.scatter(df['MentHlth'], df['PhysHlth'], color='green', alpha=0.6)
plt.title('Mental Health Days vs. Physical Health Days')
plt.xlabel('Mental Health Days')
plt.ylabel('Physical Health Days')

plt.tight_layout(pad=3.0)  # Add padding between subplots
plt.show()

### 2. Correlation Matrix ###
# Select continuous variables for the correlation matrix
continuous_vars = ['BMI', 'MentHlth', 'PhysHlth', 'Age']
# Calculate the correlation matrix
corr_matrix = df[continuous_vars].corr()
# Plot the heatmap with updated color map
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='viridis', linewidths=0.5, vmin=-1, vmax=1) 
plt.title('Correlation Matrix of Continuous Variables')
plt.show()
# Out:
# C:\Users\bhagw\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# c. Compare Heart Disease Across Demographic Groups:
# Analyze the prevalence of heart disease across different demographic groups (e.g., age, gender, education) using bar charts or pivot tables.

# %%
sns.set(style="whitegrid")

### 1. Analyze Heart Disease by Age Group ###
age_counts = df.groupby(['Age', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)
age_counts.plot(kind='bar', stacked=True, color=['lightgreen', 'lightcoral'], figsize=(10, 5))
plt.title('Heart Disease Prevalence by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\2356577485.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_counts = df.groupby(['Age', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %%
### 2. Analyze Heart Disease by Gender ###
sex_counts = df.groupby(['Sex', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)
sex_counts.plot(kind='bar', stacked=True, color=['lightgreen', 'lightcoral'], figsize=(10, 5))
plt.title('Heart Disease Prevalence by Gender')
plt.xlabel('Gender (0 = Male, 1 = Female)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\2944552105.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sex_counts = df.groupby(['Sex', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %%
### 3. Analyze Heart Disease by Education Level ###
education_counts = df.groupby(['Education', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)
education_counts.plot(kind='bar', stacked=True, color=['lightgreen', 'lightcoral'], figsize=(10, 5))
plt.title('Heart Disease Prevalence by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\482690086.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   education_counts = df.groupby(['Education', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %%
### 4. Compare Heart Disease Across Income Levels ###
income_counts = df.groupby(['Income', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

plt.figure(figsize=(10, 5))
income_counts.plot(kind='bar', stacked=False, color=['lightgreen', 'lightcoral'], ax=plt.gca())
plt.title('Heart Disease Prevalence Across Income Levels')
plt.xlabel('Income Level')
plt.ylabel('Count')
plt.xticks(ticks=range(len(income_counts)), labels=[f'Level {i}' for i in income_counts.index], rotation=0)
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# C:\Users\bhagw\AppData\Local\Temp\ipykernel_10544\3745715997.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   income_counts = df.groupby(['Income', 'HeartDiseaseorAttack']).size().unstack(fill_value=0)

# %% [markdown]
# # Conclusion:-
#
# The analysis of the dataset reveals significant insights into the prevalence of heart disease and its correlation with various health indicators. Approximately 10% of individuals reported having heart disease or a heart attack, with a notable association between heart disease and conditions such as high blood pressure (67%) and high cholesterol (62%).
#
# Higher Body Mass Index (BMI) levels among those with heart disease suggest obesity plays a critical role in cardiovascular risk. Additionally, smokers accounted for nearly 50% of individuals with heart disease, highlighting the impact of smoking on heart health. Physical activity emerged as a protective factor, with 80% of those without heart disease reporting regular exercise, while those with heart disease experienced more days of poor mental health.
#
# Gender disparities were evident, as men reported higher heart disease rates, and socioeconomic factors, including education and income, correlated with lower disease prevalence. The correlation matrix confirmed that higher BMI was positively associated with high blood pressure and high cholesterol. These findings underscore the need for public health initiatives focused on education, regular screenings, and promoting physical activity to mitigate heart disease risks and enhance overall population health.
